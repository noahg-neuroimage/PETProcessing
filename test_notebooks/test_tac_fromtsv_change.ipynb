# %% [markdown]
# Changing the default load behavior of TACs. Need to test EVERYTHING to make sure it's all smooth.

# %%
from petpal.utils.time_activity_curve import TimeActivityCurve

# %% [markdown]
# Test blood input changes

# %%
from petpal.input_function.blood_input import resample_blood_data_on_scanner_times

resample_blood_data_on_scanner_times(
    blood_tac_path=r'W:\usr\Noah\PETPAL\repo\PETProcessing\data\tcm_tacs\turku_pet_center_fdg_plasma_clamp.txt',
    out_tac_path=r'W:\usr\Noah\PETPAL\repo\PETProcessing\test_notebooks\data\blood_tac_resampled',
    reference_4dpet_img_path=r'W:\data_archive\VATDYS\sub-VATDYS046\pet\sub-VATDYS046_pet.nii.gz',
    lin_fit_thresh_in_mins=0.5,
    rescale_constant=1
)

# %% [markdown]
# Test graphical analysis changes
